# %% [markdown]
# <a href="https://colab.research.google.com/github/iftekharwasiyu/Wasii--ISYS2001/blob/main/Weather_Adventures_Pseudocode_20304737.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Weather Adventure**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Part One:** **Basic Concepts in Pseudocode**

# %% [markdown]
# Q1. Write pseudocode for a program that suggests what to wear based on the temperature. If it’s above 25°C, suggest light clothing. If it’s between 15°C and 25°C, suggest a light jacket. If it’s below 15°C, suggest warm clothing.

# %%
temp = float(input("what is temperature today"))
if (temp>25):
   print("hot day")
if (temp>15 and temp<25):
   print("normal day")
if (temp<15):
   print("cold day")
# Out:
# what is temperature today24
# normal day

# %% [markdown]
# Q2. Create pseudocode for a program that checks if it’s a good day for a picnic. It’s a good day if it’s not raining AND the temperature is between 20°C and 30°C.

# %%
from ast import And
temp = float(input("what is temperature today"))
rain = (input("is it raining"))
if (temp>20 and temp<30 and rain=="no"):
   print("good day for picnic")
else:
   print("bad day for picnic")
# Out:
# what is temperature today25
# is it rainingno
# good day for picnic

# %% [markdown]
# Q3. Write pseudocode for a program that counts the number of rainy days in a week. Use a loop to check each day’s weather condition.

# %%
rainy_days_count = 0

for day in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]:
    weather = input(f"Is it rainy on {day}? (yes/no): ").strip().lower()

    if weather == "yes":
        rainy_days_count += 1

print(f"Total number of rainy days in the week: {rainy_days_count}")
# Out:
# Is it rainy on Monday? (yes/no): yes
# Is it rainy on Tuesday? (yes/no): no
# Is it rainy on Wednesday? (yes/no): yes
# Is it rainy on Thursday? (yes/no): no
# Is it rainy on Friday? (yes/no): yes
# Is it rainy on Saturday? (yes/no): yes
# Is it rainy on Sunday? (yes/no): no
# Total number of rainy days in the week: 4

# %% [markdown]
# Q4. Create pseudocode for a program that calculates the average temperature for a 5-day period. Use a loop to input temperatures and calculate the average.

# %%
total_temperature = 0

# Loop for 5 days
for day in range(5):
    temperature = float(input(f"Enter the temperature for day {day + 1}: "))
    total_temperature += temperature

average_temperature = total_temperature / 5
print("Average temperature:", average_temperature)
# Out:
# Enter the temperature for day 1: 25
# Enter the temperature for day 2: 24
# Enter the temperature for day 3: 45
# Enter the temperature for day 4: 10
# Enter the temperature for day 5: 25
# Average temperature: 25.8

# %% [markdown]
# Q5. Write pseudocode for a program that issues a heat wave warning. A heat wave is when the temperature is above 35°C for three consecutive days. Use a loop and counting mechanism.

# %%
consecutive_days_above_35 = 0

# Loop for 7 days
for day in range(7):
    temperature = float(input(f"Enter the temperature for day {day + 1}: "))

    if temperature > 35:
        consecutive_days_above_35 += 1
    else:
        consecutive_days_above_35 = 0

    if consecutive_days_above_35 == 3:
        print("Heat wave warning!")
        break

if consecutive_days_above_35 < 3:
    print("No heat wave.")
# Out:
# Enter the temperature for day 1: 35
# Enter the temperature for day 2: 25
# Enter the temperature for day 3: 35
# Enter the temperature for day 4: 40
# Enter the temperature for day 5: 50
# Enter the temperature for day 6: 60
# Heat wave warning!

# %% [markdown]
# **Part Two: Structuring English Descriptions into Pseudocode**

# %% [markdown]
# Q6. Read the following paragraph and structure it into pseudocode:
#
# “A weather station needs to monitor air quality. It measures the Air Quality Index (AQI) every hour. If the AQI is above 150, it should trigger an alert. The station should continue monitoring until it has recorded 24 readings or until an alert has been triggered, whichever comes first.”

# %%
reading_count = 0
alert_triggered = False

while reading_count < 24 and not alert_triggered:
    aqi = float(input(f"Enter AQI for reading {reading_count + 1}: "))

    if aqi > 150:
        print("Alert: AQI above 150!")
        alert_triggered = True
    else:
        reading_count += 1

if not alert_triggered:
    print("Monitoring complete. No alerts.")
# Out:
# Enter AQI for reading 1: 151
# Alert: AQI above 150!

# %% [markdown]
# Q7. Convert this weather forecasting process into pseudocode:
#
# “To predict tomorrow’s weather, we look at today’s temperature, humidity, and wind speed. If today’s temperature is higher than yesterday’s and the humidity is increasing, we predict a higher chance of rain. If the wind speed is also increasing, we predict stormy weather. Otherwise, if temperature and humidity are stable, we predict similar weather to today. We continue this process for a 7-day forecast.”

# %%
for day in range(7):
    print(f"Day {day + 1}:")

    today_temperature = float(input("Enter today's temperature in °C: "))
    yesterday_temperature = float(input("Enter yesterday's temperature in °C: "))
    today_humidity = float(input("Enter today's humidity percentage: "))
    yesterday_humidity = float(input("Enter yesterday's humidity percentage: "))
    today_wind_speed = float(input("Enter today's wind speed in km/h: "))
    yesterday_wind_speed = float(input("Enter yesterday's wind speed in km/h: "))

    if (today_temperature > yesterday_temperature) and (today_humidity > yesterday_humidity):
        if today_wind_speed > yesterday_wind_speed:
            print("Predicted Weather: Stormy weather.")
        else:
            print("Predicted Weather: Higher chance of rain.")
    elif (today_temperature == yesterday_temperature) and (today_humidity == yesterday_humidity):
        print("Predicted Weather: Similar weather to today.")
    else:
        print("Predicted Weather: No significant change.")
# Out:
# Day 1:
# Enter today's temperature in °C: 65
# Enter yesterday's temperature in °C: 21
# Enter today's humidity percentage: 32
# Enter yesterday's humidity percentage: 15
# Enter today's wind speed in km/h: 45
# Enter yesterday's wind speed in km/h: 54
# Predicted Weather: Higher chance of rain.
# Day 2:
# Enter today's temperature in °C: 64
# Enter yesterday's temperature in °C: 61
# Enter today's humidity percentage: 21
# Enter yesterday's humidity percentage: 64
# Enter today's wind speed in km/h: 31
# Enter yesterday's wind speed in km/h: 51
# Predicted Weather: No significant change.
# Day 3:
# Enter today's temperature in °C: 64
# Enter yesterday's temperature in °C: 61
# Enter today's humidity percentage: 65
# Enter yesterday's humidity percentage: 61
# Enter today's wind speed in km/h: 65
# Enter yesterday's wind speed in km/h: 61
# Predicted Weather: Stormy weather.
# Day 4:
# Enter today's temperature in °C: 65
# Enter yesterday's temperature in °C: 61
# ...

# %% [markdown]
# Q8. Transform this severe weather alert system into pseudocode:
#
# “A severe weather alert system monitors temperature, wind speed, and precipitation. It issues different levels of alerts based on combinations of these factors. A ‘Yellow Alert’ is issued if any two of the following conditions are met: temperature above 35°C, wind speed above 60 km/h, or precipitation above 30 mm/hour. An ‘Orange Alert’ is issued if all three conditions are met. A ‘Red Alert’ is issued if any of the conditions are: temperature above 40°C, wind speed above 100 km/h, or precipitation above 50 mm/hour. The system checks conditions every 30 minutes and maintains the highest level alert until conditions improve.”

# %%
import time

current_alert = "No Alert"

while True:
    print("Enter current weather conditions:")

    temperature = float(input("Enter temperature in °C: "))
    wind_speed = float(input("Enter wind speed in km/h: "))
    precipitation = float(input("Enter precipitation in mm/hour: "))

    if temperature > 40 or wind_speed > 100 or precipitation > 50:
        current_alert = "Red Alert"

    elif temperature > 35 and wind_speed > 60 and precipitation > 30:
        current_alert = "Orange Alert"

    elif (temperature > 35 and wind_speed > 60) or (temperature > 35 and precipitation > 30) or (wind_speed > 60 and precipitation > 30):
        current_alert = "Yellow Alert"

    print("Current Alert Level:", current_alert)

    time.sleep(30 * 60)  # 30 minutes in seconds
# Out:
# Enter current weather conditions:
# Enter temperature in °C: 65
# Enter wind speed in km/h: 50
# Enter precipitation in mm/hour: 3
# Current Alert Level: Red Alert

# %% [markdown]
# **Part Three: Reflection and Analysis**

# %% [markdown]
# Q9. Look back at your pseudocode for questions 6-8. Identify which parts were the most challenging to structure logically. Why do you think these were difficult?

# %% [markdown]
# Answer: The hardest parts for me were figuring out the complicated rules and making sure the alerts are given in the right order. It was tough because I had to keep track of many different factors and how they affect each other. As more things came into play, it got more complicated to manage everything correctly.

# %% [markdown]
# Q10. For one of the complex scenarios (questions 6-8), list three questions you would ask a GenAI tutor to help you refine or improve your pseudocode solution.

# %% [markdown]
# Answer: Here are three questions I might ask a GenAI tutor to help improve my severe weather alert system pseudocode:
#
# "How do I make sure the system always gives the most serious alert when multiple conditions are met?"
#
# I want to ensure that if several conditions trigger different alerts, the system prioritizes the most severe alert, like a Red Alert.
# "Can you show me how to make the pseudocode more efficient so it updates the alert level correctly without doing unnecessary checks?"
#
# I need advice on how to set up the pseudocode to update the alert level quickly and accurately without extra work.
# "How should I adjust the pseudocode so it can lower the alert level if the weather conditions get better?"
#
# I want to know how to change the pseudocode so it can correctly lower the alert level if the weather improves.

# %% [markdown]
# Q11. Choose one of your pseudocode solutions and describe how you would extend it to handle more complex scenarios or additional weather factors.

# %% [markdown]
# Answer: To extend the severe weather alert system to handle more complex scenarios, I would start by incorporating additional weather factors such as air pressure and visibility. By including these elements, the system can provide more comprehensive alerts. For instance, very low air pressure and poor visibility might indicate severe weather conditions that require immediate attention. Additionally, I would adjust the alert criteria to account for these new factors, ensuring that the most appropriate alert level is issued based on a combination of all monitored conditions. To further enhance accuracy, the system could use historical weather data to predict trends and adjust alerts accordingly. This way, it not only reacts to current conditions but also considers past patterns to provide a more reliable forecast. Finally, the system should include logic to downgrade alerts if weather conditions improve, ensuring that the alert level accurately reflects the changing weather. This approach will make the alert system more robust and responsive to varying and complex weather scenarios.
